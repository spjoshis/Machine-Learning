# %% [markdown]
# # Install Libraries

# %%
import sys
print(sys.executable)
# Out:
# /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/bin/python

# %%
# !/Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/bin/python -m pip install -r requirement.txt

import pandas as pd
# Out:
# Requirement already satisfied: notebook in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from -r requirement.txt (line 1)) (6.4.5)
# Requirement already satisfied: pandas in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from -r requirement.txt (line 2)) (1.4.0)
# Collecting matplotlib
#   Using cached matplotlib-3.5.1-cp38-cp38-macosx_10_9_x86_64.whl (7.3 MB)
# Requirement already satisfied: numpy in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from -r requirement.txt (line 4)) (1.21.4)
# Collecting seaborn
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# Collecting pandas_datareader
#   Using cached pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Requirement already satisfied: jupyter-client>=5.3.4 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from notebook->-r requirement.txt (line 1)) (7.0.6)
# Requirement already satisfied: jinja2 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from notebook->-r requirement.txt (line 1)) (3.0.3)
# Requirement already satisfied: pyzmq>=17 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from notebook->-r requirement.txt (line 1)) (22.3.0)
# Requirement already satisfied: ipython-genutils in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from notebook->-r requirement.txt (line 1)) (0.2.0)
# Requirement already satisfied: nbformat in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from notebook->-r requirement.txt (line 1)) (5.1.3)
# Requirement already satisfied: traitlets>=4.2.1 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from notebook->-r requirement.txt (line 1)) (5.1.1)
# Requirement already satisfied: nbconvert in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from notebook->-r requirement.txt (line 1)) (6.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from notebook->-r requirement.txt (line 1)) (0.12.1)
# Requirement already satisfied: tornado>=6.1 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from notebook->-r requirement.txt (line 1)) (6.1)
# Requirement already satisfied: ipykernel in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from notebook->-r requirement.txt (line 1)) (6.5.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from notebook->-r requirement.txt (line 1)) (4.9.1)
# Requirement already satisfied: argon2-cffi in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from notebook->-r requirement.txt (line 1)) (21.1.0)
# Requirement already satisfied: prometheus-client in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from notebook->-r requirement.txt (line 1)) (0.12.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from notebook->-r requirement.txt (line 1)) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from pandas->-r requirement.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from pandas->-r requirement.txt (line 2)) (2021.3)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from matplotlib->-r requirement.txt (line 3)) (2.4.7)
# Collecting pillow>=6.2.0
#   Using cached Pillow-9.0.0-cp38-cp38-macosx_10_10_x86_64.whl (3.0 MB)
# Requirement already satisfied: packaging>=20.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from matplotlib->-r requirement.txt (line 3)) (21.2)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.3.2-cp38-cp38-macosx_10_9_x86_64.whl (61 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.28.5-py3-none-any.whl (890 kB)
# Collecting scipy>=1.0
#   Using cached scipy-1.7.3-cp38-cp38-macosx_10_9_x86_64.whl (33.0 MB)
# Collecting requests>=2.19.0
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Requirement already satisfied: lxml in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from pandas_datareader->-r requirement.txt (line 6)) (4.6.4)
# Requirement already satisfied: entrypoints in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from jupyter-client>=5.3.4->notebook->-r requirement.txt (line 1)) (0.3)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from jupyter-client>=5.3.4->notebook->-r requirement.txt (line 1)) (1.5.1)
# Requirement already satisfied: six>=1.5 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->-r requirement.txt (line 2)) (1.16.0)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
# Collecting charset-normalizer~=2.0.0
#   Using cached charset_normalizer-2.0.10-py3-none-any.whl (39 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.8-py2.py3-none-any.whl (138 kB)
# Requirement already satisfied: ptyprocess in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from terminado>=0.8.3->notebook->-r requirement.txt (line 1)) (0.7.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from argon2-cffi->notebook->-r requirement.txt (line 1)) (1.15.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from ipykernel->notebook->-r requirement.txt (line 1)) (0.1.3)
# Requirement already satisfied: appnope in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from ipykernel->notebook->-r requirement.txt (line 1)) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from ipykernel->notebook->-r requirement.txt (line 1)) (1.5.1)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from ipykernel->notebook->-r requirement.txt (line 1)) (7.29.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from jinja2->notebook->-r requirement.txt (line 1)) (2.0.1)
# Requirement already satisfied: bleach in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from nbconvert->notebook->-r requirement.txt (line 1)) (4.1.0)
# Requirement already satisfied: testpath in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from nbconvert->notebook->-r requirement.txt (line 1)) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from nbconvert->notebook->-r requirement.txt (line 1)) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from nbconvert->notebook->-r requirement.txt (line 1)) (0.5.8)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from nbconvert->notebook->-r requirement.txt (line 1)) (1.5.0)
# Requirement already satisfied: defusedxml in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from nbconvert->notebook->-r requirement.txt (line 1)) (0.7.1)
# Requirement already satisfied: pygments>=2.4.1 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from nbconvert->notebook->-r requirement.txt (line 1)) (2.10.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from nbconvert->notebook->-r requirement.txt (line 1)) (0.8.4)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from nbformat->notebook->-r requirement.txt (line 1)) (4.2.1)
# Requirement already satisfied: pycparser in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->-r requirement.txt (line 1)) (2.21)
# Requirement already satisfied: pexpect>4.3 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirement.txt (line 1)) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirement.txt (line 1)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirement.txt (line 1)) (3.0.22)
# Requirement already satisfied: setuptools>=18.5 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirement.txt (line 1)) (57.0.0)
# Requirement already satisfied: backcall in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirement.txt (line 1)) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirement.txt (line 1)) (0.18.0)
# Requirement already satisfied: decorator in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirement.txt (line 1)) (5.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->-r requirement.txt (line 1)) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->-r requirement.txt (line 1)) (21.2.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->-r requirement.txt (line 1)) (5.4.0)
# Requirement already satisfied: webencodings in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from bleach->nbconvert->notebook->-r requirement.txt (line 1)) (0.5.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema!=2.5.0,>=2.4->nbformat->notebook->-r requirement.txt (line 1)) (3.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirement.txt (line 1)) (0.8.2)
# Requirement already satisfied: wcwidth in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirement.txt (line 1)) (0.2.5)
# Installing collected packages: urllib3, pillow, kiwisolver, idna, fonttools, cycler, charset-normalizer, certifi, scipy, requests, matplotlib, seaborn, pandas-datareader
# Successfully installed certifi-2021.10.8 charset-normalizer-2.0.10 cycler-0.11.0 fonttools-4.28.5 idna-3.3 kiwisolver-1.3.2 matplotlib-3.5.1 pandas-datareader-0.10.0 pillow-9.0.0 requests-2.27.1 scipy-1.7.3 seaborn-0.11.2 urllib3-1.26.8

# %%
# !/Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/bin/python -m pip install yfinance --upgrade --no-cache-dir
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.69-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: lxml>=4.5.1 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from yfinance) (4.6.4)
# Requirement already satisfied: requests>=2.26 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from yfinance) (2.27.1)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.10.tar.gz (8.2 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.15 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from yfinance) (1.21.4)
# Requirement already satisfied: pandas>=0.24 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from yfinance) (1.4.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from requests>=2.26->yfinance) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from requests>=2.26->yfinance) (2.0.10)
# Requirement already satisfied: six>=1.5 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=0.24->yfinance) (1.16.0)
# Building wheels for collected packages: multitasking
#   Building wheel for multitasking (setup.py) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.10-py3-none-any.whl size=8500 sha256=b175a401e840fdbe485d6f933e7ffbc0727d035dfc025f628b9d776556f4b352
#   Stored in directory: /private/var/folders/9l/n7bj18r50b166tr2vf17df900000gp/T/pip-ephem-wheel-cache-6b7g8pef/wheels/21/c9/66/b41c847de65c7985db52ec21d59996841598b8b0e93f2b9500
# Successfully built multitasking
# Installing collected packages: multitasking, yfinance
# Successfully installed multitasking-0.0.10 yfinance-0.1.69

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from pandas_datareader import data as pdr
from pandas_datareader.data import DataReader
from datetime import datetime

# import fix_yahoo_finance as yf

from collections import deque
import random

# %%
# !/Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/bin/python -m pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.7.0-cp38-cp38-macosx_10_11_x86_64.whl (207.1 MB)
#      |████████████████████████████████| 207.1 MB 155 kB/s
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from tensorflow) (0.36.2)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 10.8 MB/s
# Requirement already satisfied: numpy>=1.14.5 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from tensorflow) (1.21.4)
# Collecting flatbuffers<3.0,>=1.12
#   Downloading flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Collecting libclang>=9.0.1
#   Downloading libclang-12.0.0-2-py2.py3-none-macosx_10_9_x86_64.whl (12.2 MB)
#      |████████████████████████████████| 12.2 MB 11.4 MB/s
# Collecting keras<2.8,>=2.7.0rc0
#   Downloading keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 51.8 MB/s
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 8.4 MB/s
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.43.0-cp38-cp38-macosx_10_10_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 31.8 MB/s
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.19.3-cp38-cp38-macosx_10_9_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 44.4 MB/s
# Collecting h5py>=2.9.0
#   Downloading h5py-3.6.0-cp38-cp38-macosx_10_9_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 25.3 MB/s
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting absl-py>=0.4.0
#   Downloading absl_py-1.0.0-py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 39.8 MB/s
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.13.3-cp38-cp38-macosx_10_9_x86_64.whl (33 kB)
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0
#   Downloading tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
#      |████████████████████████████████| 463 kB 39.0 MB/s
# Collecting typing-extensions>=3.6.6
#   Using cached typing_extensions-4.0.1-py3-none-any.whl (22 kB)
# Collecting gast<0.5.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 2.6 MB/s
# Requirement already satisfied: six>=1.12.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from tensorflow) (1.16.0)
# Collecting tensorboard~=2.6
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 14.7 MB/s
# Collecting tensorflow-io-gcs-filesystem>=0.21.0
#   Downloading tensorflow_io_gcs_filesystem-0.23.1-cp38-cp38-macosx_10_14_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 44.1 MB/s
# Requirement already satisfied: setuptools>=41.0.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (57.0.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 32.4 MB/s
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 37.1 MB/s
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (2.27.1)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.3.3-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 37.8 MB/s
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.6-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 13.2 MB/s
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-2.0.2-py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 34.5 MB/s
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 53.8 MB/s
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-4.10.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.0.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.3)
# Requirement already satisfied: zipp>=0.5 in /Users/gopaljoshi/Documents/GitHub/Object-Detection-Python/venv/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.6.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 5.6 MB/s
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 62.5 MB/s
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4847 sha256=254e5d5ea4d98fab9ce4148bd581c54de4583d1fa4747d469647a478cc49b4fc
#   Stored in directory: /Users/gopaljoshi/Library/Caches/pip/wheels/a0/16/9c/5473df82468f958445479c59e784896fa24f4a5fc024b0f501
# Successfully built termcolor
# Installing collected packages: pyasn1, rsa, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, importlib-metadata, google-auth, werkzeug, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, wrapt, typing-extensions, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, keras-preprocessing, keras, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow
# Successfully installed absl-py-1.0.0 astunparse-1.6.3 cachetools-4.2.4 flatbuffers-2.0 gast-0.4.0 google-auth-2.3.3 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.43.0 h5py-3.6.0 importlib-metadata-4.10.1 keras-2.7.0 keras-preprocessing-1.1.2 libclang-12.0.0 markdown-3.3.6 oauthlib-3.1.1 opt-einsum-3.3.0 protobuf-3.19.3 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.8 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.7.0 tensorflow-estimator-2.7.0 tensorflow-io-gcs-filesystem-0.23.1 termcolor-1.1.0 typing-extensions-4.0.1 werkzeug-2.0.2 wrapt-1.13.3

# %%
import tensorflow.compat.v1 as tf
tf.compat.v1.disable_eager_execution()

# %%
df_full = DataReader('INFY', data_source='yahoo', start='2008-01-01', end=datetime.now())

df_full.reset_index().to_csv('INFY.csv', index=False)
df_full.head()
# Out:
#                High      Low     Open    Close      Volume  Adj Close
# Date
# 2008-01-02  5.70625  5.51000  5.67000  5.55375  26200000.0   4.071901
# 2008-01-03  5.56125  5.45125  5.55000  5.48625  21930400.0   4.022412
# 2008-01-04  5.40625  5.17750  5.37500  5.26375  21844800.0   3.859278
# 2008-01-07  5.39750  5.17875  5.19250  5.37375  29652000.0   3.939930
# 2008-01-08  5.53125  5.21250  5.53125  5.24625  25128800.0   3.846447

# %%
df = df_full.copy()
name = 'Q-learning agent'
class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []
        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999
        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed, self.action_size)
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())
    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
# Train agent

close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
